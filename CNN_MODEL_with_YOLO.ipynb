# %% [markdown]
# <a href="https://colab.research.google.com/github/fartech00/01/blob/main/CNN_MODEL_with_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile
import shutil

# Git Hub dan tasvirli malumotni yuklab olamiz
repo_url = "https://github.com/fartech00/01.git"

repo_name = "01"
repo_path = f"/content/{repo_name}"

if os.path.exists(repo_path):
    shutil.rmtree(repo_path)

# Git hub dan klon qilamiz
# !git clone {repo_url}

os.chdir(repo_path)
# Out:
# Cloning into '01'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 16 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 7.37 MiB | 16.20 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# from google.colab import files
# import shutil

# folder_path = "/content/01/images"
# zip_path = "/content/01/images.zip"


# shutil.make_archive("/content/images", 'zip', folder_path)

# files.download(zip_path)

# %%
# zip_path = "/content/01/labels.zip"
# extract_path = "/content/labels"

# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_path)

# print("Zip dan chiqdi")

# # Zip papkani topamiz va zip.dan chiqaramiz
# zip_files = [f for f in os.listdir() if f.endswith(".zip")]

# if zip_files:
#     zip_file = zip_files[0]
#     print(f"Zip fayl: {zip_file}. Ajratish...")

#     # Zipdagi fayllarni chiqarish
#     with zipfile.ZipFile(zip_file, "r") as zip_ref:
#         zip_ref.extractall(repo_path)

#     print("Zipdan ajraldi!")

#     # Mazjud zip faylni o'chirib yuborish
#     os.remove(zip_file)
# print("\nZipdan chiqqanlari:")
# print(os.listdir(repo_path))
# Out:
# Zip dan chiqdi
# Zip fayl: labels.zip. Ajratish...
# Zipdan ajraldi!
#
# Zipdan chiqqanlari:
# ['156.txt', '313.txt', '094.txt', '091.txt', '606.txt', 'TAFU_coding.ipynb', '565.txt', '442.txt', '504.txt', '069.txt', '404.txt', '055.txt', '253.txt', '192.txt', '011.txt', '354.txt', '478.txt', '188.txt', '123.txt', '353.txt', '128.txt', '467.txt', '255.txt', '500.txt', '347.txt', '217.txt', '319.txt', '010.txt', '374.txt', '414.txt', '528.txt', '539.txt', '573.txt', '435.txt', 'TAFU (1).ipynb', '135.txt', '163.txt', '441.txt', 'SVM_CNN_GAN_LM.ipynb', '383.txt', '295.txt', '107.txt', '600.txt', 'images.zip', '437.txt', '506.txt', '039.txt', '118.txt', '.git', '005.txt', '258.txt', '062.txt', '169.txt', '472.txt', '289.txt']

# %%
# zip_path = "/content/01/labels.zip"
# extract_path = "/content/labels"

# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_path)

# print("Zip dan chiqdi")

# # Zip papkani topamiz va zip.dan chiqaramiz
# zip_files = [f for f in os.listdir() if f.endswith(".zip")]

# if zip_files:
#     zip_file = zip_files[0]
#     print(f"Zip fayl: {zip_file}. Ajratish...")

#     # Zipdagi fayllarni chiqarish
#     with zipfile.ZipFile(zip_file, "r") as zip_ref:
#         zip_ref.extractall(repo_path)

#     print("Zipdan ajraldi!")

#     # Mazjud zip faylni o'chirib yuborish
#     os.remove(zip_file)
# print("\nZipdan chiqqanlari:")
# print(os.listdir(repo_path))

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()

# %%
# !yolo train model=yolo11n.pt data=/content/data.yaml epochs=5 imgsz=640
