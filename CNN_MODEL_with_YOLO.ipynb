# %% [markdown]
# <a href="https://colab.research.google.com/github/fartech00/01/blob/main/CNN_MODEL_with_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import zipfile
import shutil

# Git Hub dan tasvirli malumotni yuklab olamiz
repo_url = "https://github.com/fartech00/01.git"

repo_name = "01"
repo_path = f"/content/{repo_name}"

if os.path.exists(repo_path):
    shutil.rmtree(repo_path)

# Git hub dan klon qilamiz
# !git clone {repo_url}

os.chdir(repo_path)
# Out:
# Cloning into '01'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 25 (delta 8), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), 7.38 MiB | 21.98 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# from google.colab import files
# import shutil

# folder_path = "/content/01/images"
# zip_path = "/content/01/images.zip"


# shutil.make_archive("/content/images", 'zip', folder_path)

# files.download(zip_path)

# %%
zip_path = "/content/01/data.zip"
extract_path = "/content/l"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Zip dan chiqdi")

# Zip papkani topamiz va zip.dan chiqaramiz
zip_files = [f for f in os.listdir() if f.endswith(".zip")]

if zip_files:
    zip_file = zip_files[0]
    print(f"Zip fayl: {zip_file}. Ajratish...")

    # Zipdagi fayllarni chiqarish
    with zipfile.ZipFile(zip_file, "r") as zip_ref:
        zip_ref.extractall(repo_path)

    print("Zipdan ajraldi!")

    # Mazjud zip faylni o'chirib yuborish
    os.remove(zip_file)
print("\nZipdan chiqqanlari:")
print(os.listdir(repo_path))
# Out:
# Zip dan chiqdi
# Zip fayl: labels.zip. Ajratish...
# Zipdan ajraldi!
#
# Zipdan chiqqanlari:
# ['156.txt', '313.txt', '094.txt', 'data.yaml', '091.txt', '606.txt', 'TAFU_coding.ipynb', 'data.zip', '565.txt', '442.txt', '504.txt', '069.txt', '404.txt', '055.txt', '253.txt', '192.txt', '011.txt', '354.txt', '478.txt', '188.txt', '123.txt', '353.txt', '128.txt', '467.txt', '255.txt', '500.txt', 'CNN_MODEL_with_YOLO.ipynb', '347.txt', '217.txt', '319.txt', '010.txt', '374.txt', '414.txt', '528.txt', '539.txt', '573.txt', '435.txt', 'TAFU (1).ipynb', '135.txt', '163.txt', '441.txt', 'SVM_CNN_GAN_LM.ipynb', '383.txt', '295.txt', '107.txt', '600.txt', 'images.zip', '437.txt', '506.txt', '039.txt', '118.txt', '.git', '005.txt', '258.txt', '062.txt', '169.txt', '472.txt', '289.txt']

# %%
# zip_path = "/content/01/labels.zip"
# extract_path = "/content/labels"

# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_path)

# print("Zip dan chiqdi")

# # Zip papkani topamiz va zip.dan chiqaramiz
# zip_files = [f for f in os.listdir() if f.endswith(".zip")]

# if zip_files:
#     zip_file = zip_files[0]
#     print(f"Zip fayl: {zip_file}. Ajratish...")

#     # Zipdagi fayllarni chiqarish
#     with zipfile.ZipFile(zip_file, "r") as zip_ref:
#         zip_ref.extractall(repo_path)

#     print("Zipdan ajraldi!")

#     # Mazjud zip faylni o'chirib yuborish
#     os.remove(zip_file)
# print("\nZipdan chiqqanlari:")
# print(os.listdir(repo_path))

# %%
# !uv pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.3/107.7 GB disk)

# %%
# !yolo train model=yolo11n.pt data=/content/01/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
zip_path = "/content/test_data.zip"
extract_path = "/content/k"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Zip dan chiqdi")

# Zip papkani topamiz va zip.dan chiqaramiz
zip_files = [f for f in os.listdir() if f.endswith(".zip")]

if zip_files:
    zip_file = zip_files[0]
    print(f"Zip fayl: {zip_file}. Ajratish...")

    # Zipdagi fayllarni chiqarish
    with zipfile.ZipFile(zip_file, "r") as zip_ref:
        zip_ref.extractall(repo_path)

    print("Zipdan ajraldi!")

    # Mazjud zip faylni o'chirib yuborish
    os.remove(zip_file)
print("\nZipdan chiqqanlari:")
print(os.listdir(repo_path))
# Out:
# Zip dan chiqdi
# Zip fayl: data.zip. Ajratish...
# Zipdan ajraldi!
#
# Zipdan chiqqanlari:
# ['156.txt', 'data', '313.txt', '094.txt', 'data.yaml', '091.txt', '606.txt', 'TAFU_coding.ipynb', '565.txt', '442.txt', '504.txt', '069.txt', '404.txt', '055.txt', '253.txt', '192.txt', '011.txt', '354.txt', '478.txt', '188.txt', '123.txt', '353.txt', '128.txt', '467.txt', '255.txt', 'yolo11n.pt', '500.txt', 'CNN_MODEL_with_YOLO.ipynb', '347.txt', '217.txt', '319.txt', '010.txt', '374.txt', '414.txt', '528.txt', '539.txt', '573.txt', '435.txt', 'TAFU (1).ipynb', 'runs', '135.txt', '163.txt', '441.txt', 'SVM_CNN_GAN_LM.ipynb', '383.txt', '295.txt', '107.txt', '600.txt', 'images.zip', '437.txt', '506.txt', '039.txt', '118.txt', '.git', '005.txt', '258.txt', '062.txt', '169.txt', '472.txt', '289.txt']

# %%
# !yolo predict model='/content/01/runs/detect/train/weights/best.pt' source='/content/k/test_data/lion_992d.jpg'
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/k/test_data/lion_992d.jpg: 384x640 (no detections), 237.2ms
# Speed: 11.2ms preprocess, 237.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/01/runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

model = YOLO('/')

results = model.predict(source='/content/k/test_data/liger.jpg', conf=0.25, save=True)


for result in results:
    boxes = result.boxes
# Out:
# image 1/1 /content/k/test_data/liger.jpg: 640x640 (no detections), 290.0ms
# Speed: 12.3ms preprocess, 290.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/01/runs/detect/predict
